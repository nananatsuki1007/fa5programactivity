# %% [markdown]
# <a href="https://colab.research.google.com/github/nananatsuki1007/fa5programactivity/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def total_price(a, b):
  return a * b

num1 = float(input("Input price of item!! "))
num2 = int(input("How many did you buy? "))

print("The total price is.. ", total_price(num1, num2))
# Out:
# Input price of item!! 1.99
# How many did you buy? 10
# The total price is..  19.9
